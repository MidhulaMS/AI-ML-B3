# %% [markdown]
# # Intermediate Python Assessment
#
# Welcome to the assessment!
# This notebook contains 3 challenges. Please read the instructions carefully and complete each task in the provided code cells.
#
#
# **Rules:**
# - Do not change function names or signatures.
# - Write clean, well-documented code.
# - Run all cells before submission.

# %% [markdown]
# ## Challenge 1: Word Frequency Analyzer
# Write a function `top_k_words(filename: str, k: int) -> list` that returns the top k frequent words.
# - Ignore case and punctuation.
# - Sort by frequency, then alphabetically.

# %%
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
    with open("sample.txt", "r") as f:
        text = f.read().lower()
    word_counts = Counter(words)

    return [word , count in word_counts]



# Sample Test (create a sample file)
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2821/2825480709.py in <cell line: 0>()
#      15     f.write("Data science is evolving. Python is versatile. Learning never stops.")
#      16
# ---> 17 print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
#
# /tmp/ipykernel_2821/2825480709.py in top_k_words(filename, k)
#       5     with open("sample.txt", "r") as f:
#       6         text = f.read().lower()
# ----> 7     word_counts = Counter(words)
#       8
#       9     return [word , count in word_counts]
#
# NameError: name 'words' is not defined

# %% [markdown]
# ## Challenge 2 : Analyze daily expenses and extract insights.
# User enters:
#
# Number of transactions
# Category and amount
#
# Food 200
# Travel 500
# Food 300
# Shopping 700
#
# ### Output
# * Total expense
# * Highest expense category
# * Category-wise total

# %%
def analyze_expenses():
    n = int(input("Enter number of transactions: "))

    expenses = {}

    for _ in range(n):
        category, amount = input().split()
        amount = float(amount)
        category = str(category)

    category_food = 200 +300
    category_travel = 500
    category_shopping = 700  # TODO: store category-wise total
    total = category_food + category_travel + category_shopping  # TODO: calculate total expense
    highest = max(category_food, category_travel)
    highest_category = max(highest, category_shopping)

    # TODO: find highest category

    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)

analyze_expenses()
# Out:
# Enter number of transactions: 2
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2821/2105393804.py in <cell line: 0>()
#      23     print("Category-wise:", expenses)
#      24
# ---> 25 analyze_expenses()
#
# /tmp/ipykernel_2821/2105393804.py in analyze_expenses()
#       5
#       6     for _ in range(n):
# ----> 7         category, amount = input().split()
#       8         amount = float(amount)
#       9         category = str(category)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# ### Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)
#
# 10 ,20 ,abc ,30 ,-5 , 40
#
# * Remove invalid values
# * Remove negative values
#
#
# Show:
# * Clean list
# * Average
# * Max value

# %%
import numpy as np

def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input()

        try:
            num = float(value)
            if num < 0.0:
              data.remove(num)

            data.append(num)

        except:
            # TODO: handle invalid values
            type(value) != float

    avg = np.average(data)  # TODO: calculate average
    max_val = np.max(data)        # TODO: find max

    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)
clean_data()
# Out:
# Enter number of values: 6
# 10
# 20
# abc
# 30
# -5
# 40
# Clean Data: [10.0, 20.0, 30.0, 40.0]
# Average: 25.0
# Max: 40.0
